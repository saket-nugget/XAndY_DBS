# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import DBSCAN

# %%
file_path = "D10_data.csv"
df = pd.read_csv(file_path)
df.head()
# Out:
#           x         y  label
# 0  6.428906  3.412846      1
# 1  8.226817  5.564856      1
# 2  6.091792  4.225576      1
# 3  8.449374  3.778857      1
# 4  8.299816  3.352508      1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1250 entries, 0 to 1249
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   x       1250 non-null   float64
#  1   y       1250 non-null   float64
#  2   label   1250 non-null   int64
# dtypes: float64(2), int64(1)
# memory usage: 29.4 KB

# %%
df = df.drop('label',axis=1)
df = df.dropna()

# %%
dbs = DBSCAN(eps=1.0,min_samples=3,metric='euclidean')

# %%
df['cluster'] = dbs.fit_predict(df)

# %%
df['cluster'].value_counts()
# Out:
# cluster
#  0    749
#  1    250
#  2    249
# -1      2
# Name: count, dtype: int64

# %%
sns.scatterplot(data=df,x='x',y='y',hue='cluster',s=100)
plt.show()
